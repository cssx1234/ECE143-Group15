# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tire_data=[['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'HARD', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'HARD', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'SOFT', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'INTERMEDIATE', 'MEDIUM', 'HARD', 'MEDIUM'],
  ['INTERMEDIATE', 'INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'INTERMEDIATE', 'MEDIUM', 'HARD', 'SOFT'],
  ['INTERMEDIATE', 'INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE',
   'INTERMEDIATE',
   'INTERMEDIATE',
   'MEDIUM',
   'HARD',
   'MEDIUM',
   'MEDIUM'],
  ['INTERMEDIATE', 'INTERMEDIATE', 'MEDIUM', 'HARD', 'SOFT'],
  ['INTERMEDIATE', 'INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['MEDIUM',
   'INTERMEDIATE',
   'INTERMEDIATE',
   'MEDIUM',
   'MEDIUM',
   'HARD',
   'HARD'],
  ['INTERMEDIATE', 'INTERMEDIATE', 'INTERMEDIATE'],
  ['INTERMEDIATE', 'INTERMEDIATE'],
  ['INTERMEDIATE'],
  ['INTERMEDIATE'],
  ['INTERMEDIATE'],
  ['INTERMEDIATE'],
  ['INTERMEDIATE', 'INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'MEDIUM', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'MEDIUM', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'MEDIUM', 'MEDIUM'],
  ['INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'SOFT', 'HARD'],
  ['INTERMEDIATE', 'SOFT', 'HARD'],
  ['INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'SOFT', 'MEDIUM', 'HARD'],
  ['INTERMEDIATE', 'SOFT', 'MEDIUM', 'MEDIUM'],
  ['INTERMEDIATE', 'SOFT', 'MEDIUM', 'MEDIUM', 'SOFT', 'HARD', 'HARD'],
  ['INTERMEDIATE', 'SOFT'],
  ['MEDIUM', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM'],
  ['MEDIUM', 'HARD', 'MEDIUM'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'SOFT'],
  ['MEDIUM', 'SOFT'],
  ['HARD', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'SOFT'],
  ['MEDIUM', 'SOFT'],
  ['SOFT', 'HARD'],
  ['SOFT', 'SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM'],
  ['MEDIUM', 'SOFT', 'MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'HARD', 'HARD', 'MEDIUM'],
  ['SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'HARD', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'HARD', 'HARD'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['HARD', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['HARD'],
  ['HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['HARD', 'MEDIUM'],
  ['HARD', 'MEDIUM'],
  ['MEDIUM', 'SOFT', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'SOFT', 'SOFT'],
  ['MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['MEDIUM', 'SOFT'],
  ['MEDIUM'],
  ['MEDIUM', 'SOFT', 'SOFT'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'HARD', 'SOFT'],
  ['MEDIUM', 'SOFT'],
  ['MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['HARD', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM'],
  ['MEDIUM'],
  ['MEDIUM'],
  ['HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM'],
  ['MEDIUM'],
  ['MEDIUM'],
  ['MEDIUM'],
  ['HARD'],
  ['MEDIUM'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD', 'MEDIUM'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD', 'MEDIUM'],
  ['SOFT', 'HARD'],
  ['SOFT', 'HARD'],
  ['SOFT', 'HARD'],
  ['HARD', 'MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['SOFT', 'HARD', 'HARD'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'HARD', 'MEDIUM', 'MEDIUM'],
  ['SOFT'],
  ['MEDIUM'],
  ['SOFT', 'HARD', 'SOFT', 'SOFT'],
  ['MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['SOFT'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM'],
  ['SOFT', 'HARD', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['SOFT', 'HARD', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'HARD', 'MEDIUM', 'MEDIUM'],
  ['SOFT'],
  ['MEDIUM'],
  ['SOFT', 'HARD', 'SOFT', 'SOFT'],
  ['MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['SOFT'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM'],
  ['SOFT', 'HARD', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['SOFT', 'HARD', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['HARD', 'MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD', 'HARD'],
  ['SOFT', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['HARD', 'MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM'],
  ['MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['HARD', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM'],
  ['MEDIUM'],
  ['MEDIUM'],
  ['HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM'],
  ['MEDIUM'],
  ['MEDIUM'],
  ['MEDIUM'],
  ['HARD'],
  ['MEDIUM'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['SOFT', 'MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'SOFT', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'SOFT', 'HARD', 'SOFT'],
  ['SOFT'],
  ['MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['MEDIUM', 'SOFT', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM', 'SOFT'],
  ['HARD'],
  ['MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['HARD', 'HARD', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM'],
  ['MEDIUM', 'HARD', 'MEDIUM'],
  ['MEDIUM'],
  ['HARD'],
  ['SOFT', 'HARD'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD'],
  ['SOFT', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'HARD'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['SOFT', 'HARD'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'SOFT'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['HARD', 'MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['HARD', 'MEDIUM'],
  ['HARD', 'MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['HARD', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['HARD', 'MEDIUM'],
  ['SOFT', 'HARD', 'HARD', 'SOFT'],
  ['SOFT', 'HARD', 'HARD'],
  ['SOFT', 'HARD', 'SOFT', 'SOFT', 'SOFT'],
  ['SOFT', 'HARD', 'HARD', 'SOFT'],
  ['HARD'],
  ['SOFT', 'HARD', 'HARD', 'SOFT'],
  ['SOFT', 'HARD', 'HARD', 'SOFT'],
  ['SOFT'],
  ['SOFT', 'HARD'],
  ['SOFT', 'HARD', 'HARD', 'SOFT'],
  ['SOFT', 'HARD', 'HARD', 'SOFT'],
  ['SOFT', 'HARD', 'SOFT', 'SOFT', 'SOFT'],
  ['SOFT', 'HARD', 'HARD', 'SOFT'],
  ['SOFT', 'HARD', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD', 'HARD', 'SOFT'],
  ['SOFT', 'HARD', 'SOFT', 'SOFT'],
  ['SOFT', 'HARD', 'SOFT', 'SOFT', 'SOFT', 'SOFT', 'SOFT'],
  ['SOFT', 'HARD', 'HARD', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'HARD'],
  ['HARD', 'MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'HARD', 'HARD', 'HARD', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'SOFT', 'HARD', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'MEDIUM', 'HARD'],
  ['SOFT', 'SOFT', 'MEDIUM', 'HARD'],
  ['HARD', 'MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'MEDIUM', 'MEDIUM'],
  ['HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM'],
  ['SOFT', 'MEDIUM'],
  ['MEDIUM', 'SOFT', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM'],
  ['MEDIUM', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'SOFT'],
  ['SOFT', 'HARD', 'MEDIUM'],
  ['SOFT', 'SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'SOFT', 'MEDIUM'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'SOFT', 'MEDIUM'],
  ['SOFT', 'HARD', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'SOFT', 'MEDIUM'],
  ['MEDIUM', 'SOFT'],
  ['SOFT', 'HARD', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'SOFT', 'MEDIUM'],
  ['MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'SOFT', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM'],
  ['SOFT', 'SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM'],
  ['SOFT', 'SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT', 'SOFT'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM', 'SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'SOFT', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'SOFT', 'HARD', 'SOFT'],
  ['SOFT'],
  ['MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['MEDIUM', 'SOFT', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM', 'SOFT'],
  ['HARD'],
  ['MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['HARD', 'HARD', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM'],
  ['MEDIUM', 'HARD', 'MEDIUM'],
  ['MEDIUM'],
  ['HARD'],
  ['SOFT', 'HARD'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD'],
  ['SOFT', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'HARD'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['SOFT', 'HARD'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'SOFT'],
  ['SOFT', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['MEDIUM'],
  ['SOFT', 'SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM'],
  ['MEDIUM', 'SOFT', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'HARD'],
  ['HARD', 'MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'HARD', 'HARD', 'HARD', 'SOFT'],
  ['MEDIUM', 'MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'SOFT', 'HARD', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'MEDIUM', 'HARD'],
  ['SOFT', 'SOFT', 'MEDIUM', 'HARD'],
  ['HARD', 'MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'MEDIUM', 'MEDIUM'],
  ['HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD', 'HARD'],
  ['MEDIUM', 'MEDIUM', 'HARD'],
  ['MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['SOFT', 'MEDIUM', 'MEDIUM'],
  ['MEDIUM', 'HARD', 'MEDIUM'],
  ['MEDIUM', 'HARD', 'HARD', 'MEDIUM'],
  ['MEDIUM'],
  ['MEDIUM', 'HARD', 'MEDIUM'],
  ['SOFT', 'SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'HARD'],
  ['SOFT', 'MEDIUM', 'SOFT', 'SOFT'],
  ['SOFT', 'MEDIUM', 'HARD', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM', 'SOFT'],
  ['MEDIUM', 'SOFT', 'HARD', 'SOFT'],
  ['SOFT', 'MEDIUM', 'HARD', 'SOFT'],
  ['MEDIUM', 'HARD', 'SOFT', 'SOFT'],
  ['SOFT', 'HARD', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'SOFT', 'MEDIUM', 'SOFT'],
  ['SOFT', 'HARD', 'MEDIUM', 'SOFT'],
  ['SOFT', 'MEDIUM', 'MEDIUM', 'SOFT']]
tire_counts = {'SOFT': 0, 'MEDIUM': 0, 'HARD': 0}
for sublist in tire_data:
    for tire in sublist:
        if tire in tire_counts:
            tire_counts[tire] += 1

tire_counts
# Out:
# {'SOFT': 559, 'MEDIUM': 839, 'HARD': 548}

# %%
# Given tire count data
tire_counts = {'SOFT': 559, 'MEDIUM': 839, 'HARD': 548}

# Creating a bar chart
plt.figure(figsize=(8, 6))
plt.bar(tire_counts.keys(), tire_counts.values(), color=['blue', 'green', 'red'])

plt.title('Tire Type Usage Counts')
plt.xlabel('Tire Type')
plt.ylabel('Usage Count')
plt.xticks(list(tire_counts.keys()))

# Display the chart
plt.show()

# %%
strategies= [
   ['SOFT', 'MEDIUM'],
   ['SOFT', 'MEDIUM', 'HARD'],
   ['MEDIUM', 'HARD'],
   ['MEDIUM', 'MEDIUM', 'HARD'],
   ['SOFT', 'MEDIUM', 'MEDIUM', 'SOFT'],
   ['MEDIUM', 'MEDIUM', 'HARD', 'HARD'],
   ['MEDIUM', 'HARD', 'HARD'],
   ['MEDIUM', 'MEDIUM'],
   ['SOFT', 'HARD'],
   ['SOFT', 'MEDIUM', 'MEDIUM'],
   ['SOFT', 'HARD', 'HARD'],
   ['MEDIUM', 'MEDIUM', 'HARD', 'MEDIUM'],
   ['SOFT', 'HARD', 'MEDIUM'],
   ['SOFT', 'MEDIUM', 'SOFT'],
   ['MEDIUM', 'HARD', 'SOFT', 'SOFT'],
   ['SOFT', 'SOFT', 'MEDIUM'],
   ['SOFT', 'HARD', 'MEDIUM', 'MEDIUM'],
   ['HARD', 'MEDIUM'],
   ['HARD', 'MEDIUM', 'HARD', 'HARD'],
   ['SOFT', 'HARD', 'SOFT', 'SOFT', 'MEDIUM'],
   ['MEDIUM', 'SOFT'],
   ['MEDIUM', 'HARD', 'SOFT'],
   ['SOFT', 'SOFT', 'MEDIUM', 'SOFT'],
   ['SOFT', 'SOFT', 'MEDIUM', 'HARD'],
   ['MEDIUM', 'SOFT', 'HARD'],
   ['MEDIUM', 'MEDIUM', 'HARD', 'MEDIUM', 'HARD'],
   ['MEDIUM', 'MEDIUM', 'SOFT'],
   ['MEDIUM', 'MEDIUM', 'HARD', 'HARD', 'HARD'],
   ['MEDIUM', 'MEDIUM', 'MEDIUM', 'HARD'],
   ['MEDIUM', 'HARD', 'MEDIUM'],
   ['MEDIUM', 'SOFT', 'HARD', 'SOFT'],
   ['SOFT', 'SOFT', 'MEDIUM', 'MEDIUM'],
   ['SOFT', 'MEDIUM', 'HARD', 'SOFT'],
   ['MEDIUM', 'MEDIUM', 'HARD', 'SOFT'],
   ['SOFT', 'MEDIUM', 'SOFT', 'SOFT'],
   ['MEDIUM', 'HARD', 'MEDIUM', 'SOFT'],
   ['MEDIUM', 'HARD', 'MEDIUM', 'HARD'],
   ['SOFT', 'HARD', 'HARD', 'SOFT'],
   ['MEDIUM', 'SOFT', 'MEDIUM'],
   ['HARD', 'MEDIUM', 'HARD']
]

position = [
   10.421807824763274,
   10.135894813226685,
   12.369066495825235,
   11.283008998736495,
   8.7781382928357,
   10.828605624405517,
   12.083153484288644,
   11.568922010273086,
   11.221952310315423,
   9.423878673401273,
   10.936039298778832,
   9.972600329883551,
   10.224023158953422,
   9.668191639829718,
   10.969709930326106,
   12.255863617943877,
   8.913614490100478,
   12.990894357912628,
   12.25057797204506,
   13.813649859258266,
   14.40090695481569,
   11.615450310891678,
   11.610123237378305,
   11.8014602436129,
   14.1149939432791,
   6.071997352739018,
   10.815305825339529,
   6.928002647260984,
   10.116589484580107,
   11.371137344463234,
   13.469253562713527,
   10.945454949090934,
   9.490154432661111,
   10.637268618170923,
   9.022451259264145,
   10.725396963897662,
   10.916733970132256,
   10.29029891821326,
   13.40297780345369,
   12.704981346376037
]

# Draw a bar chart
plt.figure(figsize=(12, 6))
plt.bar(range(len(strategies)), position, tick_label=[" / ".join(strategy) for strategy in strategies],color='red')
plt.xlabel('Strategy')
plt.ylabel('Final Position')
plt.title('Strategy and Performance')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
